# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('careem.csv')
print("Dataset")
print("Rows and Colomns",df.shape) # for row col
df # for data
# Out:
# Dataset
# Rows and Colomns (609, 37)
#         BookingID      Trip ID Service Area  ...  Credit ID Payment Type Notes
# 0    1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 1    1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 2    1.100000e+09  761000000.0    Hyderabad  ...  3224899.0  Credit Card   NaN
# 3    1.070000e+09  735000000.0      Karachi  ...  2144622.0  Credit Card   NaN
# 4    1.060000e+09  732000000.0      Karachi  ...    26218.0         Cash   NaN
# ..            ...          ...          ...  ...        ...          ...   ...
# 604  1.500000e+08   91095012.0      Karachi  ...    26218.0         Cash   NaN
# 605  1.490000e+08   90890651.0      Karachi  ...    26218.0         Cash   NaN
# 606  1.270000e+08   77233439.0      Karachi  ...    26218.0         Cash   NaN
# 607  1.110000e+08   67391036.0      Karachi  ...    26218.0         Cash   NaN
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         BookingID      Trip ID Service Area  ...  Credit ID Payment Type Notes
# 0    1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 1    1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 2    1.100000e+09  761000000.0    Hyderabad  ...  3224899.0  Credit Card   NaN
# 3    1.070000e+09  735000000.0      Karachi  ...  2144622.0  Credit Card   NaN
# 4    1.060000e+09  732000000.0      Karachi  ...    26218.0         Cash   NaN
# ..            ...          ...          ...  ...        ...          ...   ...
# 604  1.500000e+08   91095012.0      Karachi  ...    26218.0         Cash   NaN
# 605  1.490000e+08   90890651.0      Karachi  ...    26218.0         Cash   NaN
# 606  1.270000e+08   77233439.0      Karachi  ...    26218.0         Cash   NaN
# 607  1.110000e+08   67391036.0      Karachi  ...    26218.0         Cash   NaN
# ...

# %%
df.isnull()
# Out:
#      BookingID  Trip ID  Service Area  ...  Credit ID  Payment Type  Notes
# 0        False    False         False  ...      False         False   True
# 1        False    False         False  ...      False         False   True
# 2        False    False         False  ...      False         False   True
# 3        False    False         False  ...      False         False   True
# 4        False    False         False  ...      False         False   True
# ..         ...      ...           ...  ...        ...           ...    ...
# 604      False    False         False  ...      False         False   True
# 605      False    False         False  ...      False         False   True
# 606      False    False         False  ...      False         False   True
# 607      False    False         False  ...      False         False   True
# 608      False    False         False  ...      False         False   True
#
# [609 rows x 37 columns]

# %%
df.drop(['Reference Code','Rating','Tollgate','Tollgate Details GMT','Amount of Credit Used','Moving Distance','Notes'],axis=1)
df
# Out:
#         BookingID      Trip ID Service Area  ...  Credit ID Payment Type Notes
# 0    1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 1    1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 2    1.100000e+09  761000000.0    Hyderabad  ...  3224899.0  Credit Card   NaN
# 3    1.070000e+09  735000000.0      Karachi  ...  2144622.0  Credit Card   NaN
# 4    1.060000e+09  732000000.0      Karachi  ...    26218.0         Cash   NaN
# ..            ...          ...          ...  ...        ...          ...   ...
# 604  1.500000e+08   91095012.0      Karachi  ...    26218.0         Cash   NaN
# 605  1.490000e+08   90890651.0      Karachi  ...    26218.0         Cash   NaN
# 606  1.270000e+08   77233439.0      Karachi  ...    26218.0         Cash   NaN
# 607  1.110000e+08   67391036.0      Karachi  ...    26218.0         Cash   NaN
# 608  1.110000e+08   67319517.0      Karachi  ...    26218.0         Cash   NaN
#
# [609 rows x 37 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         BookingID      Trip ID Service Area  ...  Credit ID Payment Type Notes
# 0    1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 1    1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 2    1.100000e+09  761000000.0    Hyderabad  ...  3224899.0  Credit Card   NaN
# 3    1.070000e+09  735000000.0      Karachi  ...  2144622.0  Credit Card   NaN
# 4    1.060000e+09  732000000.0      Karachi  ...    26218.0         Cash   NaN
# ..            ...          ...          ...  ...        ...          ...   ...
# 604  1.500000e+08   91095012.0      Karachi  ...    26218.0         Cash   NaN
# 605  1.490000e+08   90890651.0      Karachi  ...    26218.0         Cash   NaN
# 606  1.270000e+08   77233439.0      Karachi  ...    26218.0         Cash   NaN
# 607  1.110000e+08   67391036.0      Karachi  ...    26218.0         Cash   NaN
# ...

# %%
df.head()
# Out:
#       BookingID      Trip ID Service Area  ...  Credit ID Payment Type Notes
# 0  1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 1  1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 2  1.100000e+09  761000000.0    Hyderabad  ...  3224899.0  Credit Card   NaN
# 3  1.070000e+09  735000000.0      Karachi  ...  2144622.0  Credit Card   NaN
# 4  1.060000e+09  732000000.0      Karachi  ...    26218.0         Cash   NaN
#
# [5 rows x 37 columns]

# %%
df.tail()
# Out:
#        BookingID     Trip ID Service Area  ... Credit ID Payment Type Notes
# 604  150000000.0  91095012.0      Karachi  ...   26218.0         Cash   NaN
# 605  149000000.0  90890651.0      Karachi  ...   26218.0         Cash   NaN
# 606  127000000.0  77233439.0      Karachi  ...   26218.0         Cash   NaN
# 607  111000000.0  67391036.0      Karachi  ...   26218.0         Cash   NaN
# 608  111000000.0  67319517.0      Karachi  ...   26218.0         Cash   NaN
#
# [5 rows x 37 columns]

# %%
df
# Out:
#         BookingID      Trip ID Service Area  ...  Credit ID Payment Type Notes
# 0    1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 1    1.100000e+09  761000000.0      Karachi  ...  3224899.0  Credit Card   NaN
# 2    1.100000e+09  761000000.0    Hyderabad  ...  3224899.0  Credit Card   NaN
# 3    1.070000e+09  735000000.0      Karachi  ...  2144622.0  Credit Card   NaN
# 4    1.060000e+09  732000000.0      Karachi  ...    26218.0         Cash   NaN
# ..            ...          ...          ...  ...        ...          ...   ...
# 604  1.500000e+08   91095012.0      Karachi  ...    26218.0         Cash   NaN
# 605  1.490000e+08   90890651.0      Karachi  ...    26218.0         Cash   NaN
# 606  1.270000e+08   77233439.0      Karachi  ...    26218.0         Cash   NaN
# 607  1.110000e+08   67391036.0      Karachi  ...    26218.0         Cash   NaN
# 608  1.110000e+08   67319517.0      Karachi  ...    26218.0         Cash   NaN
#
# [609 rows x 37 columns]

# %%
df.dropna(axis='columns')
# Out:
#         BookingID      Trip ID  ... Payment Price Payment Type
# 0    1.100000e+09  761000000.0  ...           313  Credit Card
# 1    1.100000e+09  761000000.0  ...           272  Credit Card
# 2    1.100000e+09  761000000.0  ...            51  Credit Card
# 3    1.070000e+09  735000000.0  ...           494  Credit Card
# 4    1.060000e+09  732000000.0  ...           182         Cash
# ..            ...          ...  ...           ...          ...
# 604  1.500000e+08   91095012.0  ...             0         Cash
# 605  1.490000e+08   90890651.0  ...           337         Cash
# 606  1.270000e+08   77233439.0  ...             0         Cash
# 607  1.110000e+08   67391036.0  ...           398         Cash
# 608  1.110000e+08   67319517.0  ...           374         Cash
#
# [609 rows x 29 columns]
